# %%
import pandas as pd
df_summary = pd.read_csv('./bbdd_rag/output.csv')
df_summary
# Out:
#                                                    title  \
# 0      Calculation of prompt diphoton production cros...
# 1               Sparsity-certifying Graph Decompositions
# 2      The evolution of the Earth-Moon system based o...
# 3      A determinant of Stirling cycle numbers counts...
# 4      From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
# ...                                                  ...
# 49995  Casimir-Polder force between an atom and a die...
# 49996  Repelling Random Walkers in a Diffusion-Coales...
# 49997  The cobordism class of the moduli space of pol...
# 49998                 Authentication over Noisy Channels
# 49999  Inclusive 1-jet Production Cross Section at Sm...
#
#                                                 abstract           categories  \
# 0        A fully differential calculation in perturba...               hep-ph
# 1        We describe a new algorithm, the $(k,\ell)$-...        math.CO cs.CG
# ...

# %%
df_lda = pd.read_csv('./lda/nuevo_dataframe_80_keywords.csv')
df_lda
# Out:
#                                                    title  \
# 0      Calculation of prompt diphoton production cros...
# 1               Sparsity-certifying Graph Decompositions
# 2      The evolution of the Earth-Moon system based o...
# 3      A determinant of Stirling cycle numbers counts...
# 4      From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
# ...                                                  ...
# 49995  Casimir-Polder force between an atom and a die...
# 49996  Repelling Random Walkers in a Diffusion-Coales...
# 49997  The cobordism class of the moduli space of pol...
# 49998                 Authentication over Noisy Channels
# 49999  Inclusive 1-jet Production Cross Section at Sm...
#
#                                                 abstract           categories  \
# 0        A fully differential calculation in perturba...               hep-ph
# 1        We describe a new algorithm, the $(k,\ell)$-...        math.CO cs.CG
# ...

# %%
df_summary['main_topics'] = df_lda['main_topics']
df_summary
# Out:
#                                                    title  \
# 0      Calculation of prompt diphoton production cros...
# 1               Sparsity-certifying Graph Decompositions
# 2      The evolution of the Earth-Moon system based o...
# 3      A determinant of Stirling cycle numbers counts...
# 4      From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
# ...                                                  ...
# 49995  Casimir-Polder force between an atom and a die...
# 49996  Repelling Random Walkers in a Diffusion-Coales...
# 49997  The cobordism class of the moduli space of pol...
# 49998                 Authentication over Noisy Channels
# 49999  Inclusive 1-jet Production Cross Section at Sm...
#
#                                                 abstract           categories  \
# 0        A fully differential calculation in perturba...               hep-ph
# 1        We describe a new algorithm, the $(k,\ell)$-...        math.CO cs.CG
# ...

# %%
import pickle 
with open('./bbdd_rag/arxiv_data.pkl', 'wb') as f:
    pickle.dump(df_summary, f)

# %%
 with open('./bbdd_rag/arxiv_data.pkl', 'rb') as f:
    read_df = pickle.load(f)
read_df
# Out:
#                                                    title  \
# 0      Calculation of prompt diphoton production cros...
# 1               Sparsity-certifying Graph Decompositions
# 2      The evolution of the Earth-Moon system based o...
# 3      A determinant of Stirling cycle numbers counts...
# 4      From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
# ...                                                  ...
# 49995  Casimir-Polder force between an atom and a die...
# 49996  Repelling Random Walkers in a Diffusion-Coales...
# 49997  The cobordism class of the moduli space of pol...
# 49998                 Authentication over Noisy Channels
# 49999  Inclusive 1-jet Production Cross Section at Sm...
#
#                                                 abstract           categories  \
# 0        A fully differential calculation in perturba...               hep-ph
# 1        We describe a new algorithm, the $(k,\ell)$-...        math.CO cs.CG
# ...
